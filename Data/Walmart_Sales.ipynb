# %% [markdown]
# <a href="https://colab.research.google.com/github/ShivaniSinghRajawat/Walmart-Sales-Analysis/blob/main/Walmart_Sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>INSTALLING KAGGLE AND DOWNLOADING KAGGLE DATASET

# %%
# !pip install kaggle

# %%
# upload kaggle.json file
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-16e0b0ae-62af-43bc-9abd-2d5fbc97bee1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-16e0b0ae-62af-43bc-9abd-2d5fbc97bee1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Create a .kaggle directory if it doesn't exist
# !mkdir -p ~/.kaggle

# %%
# copy kaggle.json file
# !cp kaggle.json ~/.kaggle/

# %%
# Set permissions for the kaggle.json file
# !chmod 600 ~/.kaggle/kaggle.json

# %%
ls -ltr /root/.kaggle
# Out:
# total 4
# -rw------- 1 root root 75 Dec  1 13:51 kaggle.json

# %%
# !kaggle datasets list -s Walmart_Sales.csv
# Out:
# ref                                          title                                 size  lastUpdated                 downloadCount  voteCount  usabilityRating
# -------------------------------------------  ------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# mikhail1681/walmart-sales                    Walmart Sales                       125107  2024-06-06 07:36:51.367000          70653        621  1.0
# eshummalik/walmart-trends                    Walmart Trends                      125107  2025-09-26 08:00:44.073000            157         21  1.0
# danielfynemankalio/walmart-sales-analysis    Walmart Sales Analysis              404551  2025-04-01 06:26:57.927000             83          1  0.8235294
# avinashbunga/walmart-weekly-sales-forecast   Walmart Weekly Sales Forecast       146732  2025-05-28 20:03:03.510000             64          0  0.8235294
# ...

# %%
# !kaggle datasets download -d 'mikhail1681/walmart-sales' \
-p ../data/kaggleDataForWalmartSalesAnalysis
# Out:
# Dataset URL: https://www.kaggle.com/datasets/mikhail1681/walmart-sales
# License(s): other
# ...
#   0% 0.00/122k [00:00<?, ?B/s]
# 100% 122k/122k [00:00<00:00, 367MB/s]

# %%
ls -ltr ../data/kaggleDataForWalmartSalesAnalysis
# Out:
# total 124
# -rw-r--r-- 1 root root 125107 Jun  6  2024 walmart-sales.zip

# %%
#unzip file
# !unzip ../data/kaggleDataForWalmartSalesAnalysis/walmart-sales.zip -d ../data/kaggleDataForWalmartSalesAnalysis
# Out:
# Archive:  ../data/kaggleDataForWalmartSalesAnalysis/walmart-sales.zip
#   inflating: ../data/kaggleDataForWalmartSalesAnalysis/Walmart_Sales.csv

# %%
ls -ltr ../data/kaggleDataForWalmartSalesAnalysis
# Out:
# total 480
# -rw-r--r-- 1 root root 363732 Jun  6  2024 Walmart_Sales.csv
# -rw-r--r-- 1 root root 125107 Jun  6  2024 walmart-sales.zip

# %%
# !chmod 777 -R ../data/kaggleDataForWalmartSalesAnalysis/Walmart_Sales.csv

# %%
ls -ltr ../data/kaggleDataForWalmartSalesAnalysis/Walmart_Sales.csv
# Out:
# -rwxrwxrwx 1 root root 363732 Jun  6  2024 ../data/kaggleDataForWalmartSalesAnalysis/Walmart_Sales.csv*

# %% [markdown]
# <H1>EXPLORATORY DATA ANALYSIS

# %%
import pandas as pd
df = pd.read_csv('../data/kaggleDataForWalmartSalesAnalysis/Walmart_Sales.csv')

# %%
df.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
df.tail(5)
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667

# %% [markdown]
# <h1>
# Upload DataFrame to Google Sheets

# %%
from google.colab import auth
import gspread
from google.auth import default

auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

print("Google Colab authenticated and gspread authorized successfully.")
# Out:
# Google Colab authenticated and gspread authorized successfully.

# %%
from gspread_dataframe import set_with_dataframe

sh = gc.create("Walmart_Sales_Data")
worksheet = sh.get_worksheet(0)
set_with_dataframe(worksheet, df)

print("DataFrame successfully uploaded to Google Sheet 'Walmart_Sales_Data'.")
# Out:
# DataFrame successfully uploaded to Google Sheet 'Walmart_Sales_Data'.
